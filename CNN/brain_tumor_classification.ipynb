# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d navoneel/brain-mri-images-for-brain-tumor-detection
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading brain-mri-images-for-brain-tumor-detection.zip to /content
#  40% 6.00M/15.1M [00:00<00:00, 56.4MB/s]
# 100% 15.1M/15.1M [00:00<00:00, 91.5MB/s]

# %%
# Our file is in zip formate so we unzip the given dataset
import zipfile
zip_ref=zipfile.ZipFile('/content/brain-mri-images-for-brain-tumor-detection.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import os

# %%
yes_brain_tumor=os.listdir('/content/brain_tumor_dataset/yes')
no_brain_tumor=os.listdir('/content/brain_tumor_dataset/no')

# %%
yes_brain_tumor[2:6]
# Out:
# ['Y38.jpg', 'Y181.jpg', 'Y40.JPG', 'Y27.jpg']

# %%
no_brain_tumor[2:6]
# Out:
# ['46 no.jpg', 'no 2.jpg', 'No16.jpg', 'N16.jpg']

# %%
len(yes_brain_tumor)
# Out:
# 155

# %%
len(no_brain_tumor)
# Out:
# 98

# %%
# here creating the labels
# here 1 represents that the patients has the brain tumor
# here 0 reperesents that the patients has not a brain tumor

# %%
yes_brain_tumor_label=[1]*len(yes_brain_tumor)
no_brain_tumor_label=[0]*len(no_brain_tumor)
labels=yes_brain_tumor_label+no_brain_tumor_label

# %%
len(labels)
# Out:
# 253

# %%
import cv2
from PIL import Image
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# displaying the image of the brain tumor
tumor=cv2.imread('/content/brain_tumor_dataset/yes/Y102.jpg')
cv2_imshow(tumor)
# Out:
# <PIL.Image.Image image mode=RGB size=587x630>

# %%
# displaying the image of that is free from the tumor
tumorless=cv2.imread('/content/brain_tumor_dataset/no/17 no.jpg')
cv2_imshow(tumorless)
# Out:
# <PIL.Image.Image image mode=RGB size=218x231>

# %%
# performing the image processing

tumor_path='/content/brain_tumor_dataset/yes/'

data=[]

for i in yes_brain_tumor:
  image=Image.open(tumor_path+i)
  image=image.resize((128,128))
  image=image.convert("RGB")
  image=np.array(image)

  data.append(image)


tumorfree_path='/content/brain_tumor_dataset/no/'

for i in no_brain_tumor:
  image=Image.open(tumorfree_path+i)
  image=image.resize((128,128))
  image=image.convert("RGB")
  image=np.array(image)
  data.append(image)

# %%
# converting the image list to numpy arrar
X=np.array(data)
y=np.array(labels)

# %%
len(X)
# Out:
# 253

# %%
len(y)
# Out:
# 253

# %%
# splitting the dataset into train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (253, 128, 128, 3) (177, 128, 128, 3) (76, 128, 128, 3)

# %%
X_train=X_train/255
X_test=X_test/255

# %%
# building the cnn model

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense,Dropout

# %%
model=Sequential()

# creating the first convolution layers
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',padding='valid',input_shape=(128,128,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=None))

model.add(Conv2D(64,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPool2D(pool_size=(2,2),strides=None))

model.add(Conv2D(128,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='sigmoid'))

# %%
# compiling the model

model.compile(optimizer='adam',loss='SparseCategoricalCrossentropy',metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=10,
    verbose=1,
    mode="auto",
    restore_best_weights=True,

)

# %%
history1=model.fit(X_train,y_train,epochs=50,callbacks=[early_stopping],validation_split=0.2,verbose=True)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 3s 79ms/step - loss: 0.7571 - accuracy: 0.5319 - val_loss: 0.6337 - val_accuracy: 0.8056
# Epoch 2/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6171 - accuracy: 0.6596 - val_loss: 0.5534 - val_accuracy: 0.7222
# Epoch 3/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5894 - accuracy: 0.6596 - val_loss: 0.5266 - val_accuracy: 0.7500
# Epoch 4/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5025 - accuracy: 0.7589 - val_loss: 0.5022 - val_accuracy: 0.7500
# Epoch 5/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5102 - accuracy: 0.7660 - val_loss: 0.4889 - val_accuracy: 0.7500
# Epoch 6/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5209 - accuracy: 0.7801 - val_loss: 0.5115 - val_accuracy: 0.7500
# Epoch 7/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4983 - accuracy: 0.8156 - val_loss: 0.4839 - val_accuracy: 0.7500
# Epoch 8/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4462 - accuracy: 0.7872 - val_loss: 0.4850 - val_accuracy: 0.8056
# Epoch 9/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.4004 - accuracy: 0.8085 - val_loss: 0.4733 - val_accuracy: 0.7500
# Epoch 10/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3647 - accuracy: 0.8440 - val_loss: 0.4495 - val_accuracy: 0.8056
# Epoch 11/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3425 - accuracy: 0.8298 - val_loss: 0.4391 - val_accuracy: 0.8333
# Epoch 12/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3463 - accuracy: 0.8511 - val_loss: 0.4357 - val_accuracy: 0.8056
# Epoch 13/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2634 - accuracy: 0.8865 - val_loss: 0.4089 - val_accuracy: 0.8333
# Epoch 14/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2806 - accuracy: 0.8865 - val_loss: 0.3875 - val_accuracy: 0.8333
# Epoch 15/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2147 - accuracy: 0.9149 - val_loss: 0.4441 - val_accuracy: 0.8333
# Epoch 16/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2329 - accuracy: 0.9007 - val_loss: 0.4063 - val_accuracy: 0.8333
# Epoch 17/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1788 - accuracy: 0.9291 - val_loss: 0.3850 - val_accuracy: 0.8333
# Epoch 18/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1097 - accuracy: 0.9645 - val_loss: 0.5321 - val_accuracy: 0.8333
# Epoch 19/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1526 - accuracy: 0.9362 - val_loss: 0.3684 - val_accuracy: 0.8333
# Epoch 20/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0859 - accuracy: 0.9787 - val_loss: 0.3506 - val_accuracy: 0.8611
# Epoch 21/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0641 - accuracy: 0.9716 - val_loss: 0.4262 - val_accuracy: 0.8611
# Epoch 22/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0886 - accuracy: 0.9787 - val_loss: 0.7045 - val_accuracy: 0.8333
# Epoch 23/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0591 - accuracy: 0.9787 - val_loss: 0.3286 - val_accuracy: 0.8611
# Epoch 24/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.3570 - val_accuracy: 0.8889
# Epoch 25/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0314 - accuracy: 0.9858 - val_loss: 0.5639 - val_accuracy: 0.8333
# Epoch 26/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0232 - accuracy: 0.9929 - val_loss: 0.7482 - val_accuracy: 0.8056
# Epoch 27/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0354 - accuracy: 0.9787 - val_loss: 0.3827 - val_accuracy: 0.8889
# Epoch 28/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0762 - accuracy: 0.9716 - val_loss: 0.3600 - val_accuracy: 0.8333
# Epoch 29/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.5573 - val_accuracy: 0.8333
# Epoch 30/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0297 - accuracy: 0.9929 - val_loss: 0.5096 - val_accuracy: 0.8889
# Epoch 31/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0268 - accuracy: 0.9929 - val_loss: 0.6935 - val_accuracy: 0.8333
# Epoch 32/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0201 - accuracy: 0.9929 - val_loss: 0.8206 - val_accuracy: 0.8056
# Epoch 33/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0140 - accuracy: 0.9922Restoring model weights from the end of the best epoch: 23.
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0128 - accuracy: 0.9929 - val_loss: 0.6334 - val_accuracy: 0.8611
# Epoch 33: early stopping

# %%
loss,accuracy=model.evaluate(X_test,y_test)
# Out:
# 3/3 [==============================] - 0s 9ms/step - loss: 1.2109 - accuracy: 0.7368

# %%
print('Test accuracy ',accuracy)
# Out:
# Test accuracy  0.7368420958518982

# %%
import matplotlib.pyplot as plt
plt.plot(history1.history['accuracy'],label='train')
plt.plot(history1.history['val_accuracy'],label='test')

plt.title("Model accuracy")
plt.xlabel("Epoch")
plt.ylabel('Accuracy')
plt.legend(loc='upper left')


plt.show()

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel('Accuracy')

plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
import pickle
pickle.dump(model,open('brain_tumor_model.pkl','wb'))

# %%
# Making  a predictive system
input_image_path=input('Enter the path of the image to be predicted:')

input_image=cv2.imread(input_image_path)
cv2_imshow(input_image)
input_image_resize=cv2.resize(input_image,(128,128))
input_image_scaled=input_image_resize/255
input_image_reshaped=np.reshape(input_image_scaled,[1,128,128,3])
input_prediction=model.predict(input_image_reshaped)
print(input_prediction)

input_pred_label=np.argmax(input_prediction)
print(input_pred_label)

if input_pred_label==1:
  print('Postive Tumor')
else:
  print("Negative Tumor")
# Out:
# Enter the path of the image to be predicted:/content/pure brain.png
# <PIL.Image.Image image mode=RGB size=482x352>
# 1/1 [==============================] - 0s 23ms/step
# [[0.6578171  0.44492832]]
# 0
# Negative Tumor
